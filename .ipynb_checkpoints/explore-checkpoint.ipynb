# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
attorneys = pd.read_csv("/Users/stellajia/Desktop/Data/data/attorneys.csv")
time = pd.read_csv("/Users/stellajia/Desktop/Data/data/attorneytimeentries.csv")
categories = pd.read_csv("/Users/stellajia/Desktop/Data/data/categories.csv")
clients = pd.read_csv("/Users/stellajia/Desktop/Data/data/categories.csv")
qs = pd.read_csv("/Users/stellajia/Desktop/Data/data/questions.csv")
qposts = pd.read_csv("/Users/stellajia/Desktop/Data/data/questionposts.csv", on_bad_lines='skip')
statesites = pd.read_csv("/Users/stellajia/Desktop/Data/data/statesites.csv")
subcats = pd.read_csv("/Users/stellajia/Desktop/Data/data/subcategories.csv")

# %%
qs.head()

# matching AskedByClientUno to clients
# Out:
#    Id StateAbbr                           QuestionUno  \
# 0   1        NC  BB53B2A4-7C1B-45C3-9693-62047889317D
# 1   2        NC  0C49F841-2782-4313-961E-7882B96D0854
# 2   3        NC  BFC28E08-B6B1-4185-A91A-89DF90816BE4
# 3   4        NC  45B24109-243A-489B-B0D2-2F36C2A369FE
# 4   5        NC  C4707F71-FE4A-4154-8174-AF00BEE2B361
#
#                             CategoryUno                      Category  \
# 0  C932D197-7F43-4BCF-BE0B-FE5F5DBCB9EF           Family and Children
# 1  C8E1275A-6C42-42E4-9B7D-231BAC438FC9             Individual Rights
# 2  C8E1275A-6C42-42E4-9B7D-231BAC438FC9             Individual Rights
# 3  C932D197-7F43-4BCF-BE0B-FE5F5DBCB9EF           Family and Children
# 4  F6016FBD-9501-4448-BCD3-BBB0E834E33B  Consumer Financial Questions
#
#                          SubcategoryUno  \
# 0  E9F87919-0CD5-4D9D-AAC6-3CBC49132F1D
# 1  73A59926-BA0B-44EC-ABF3-F4C9181EEA83
# 2  73A59926-BA0B-44EC-ABF3-F4C9181EEA83
# 3  E9F87919-0CD5-4D9D-AAC6-3CBC49132F1D
# ...

# %%
clients.head()
# Out:
#    Id StateAbbr                           CategoryUno  \
# 0   1        AK  4CB7A73E-AAB0-4E8F-94D1-8AC8610AAC64
# 1   2        AL  08C7C59B-6AAE-4BC1-83FE-BC85F1544260
# 2   3        AR  FD5059F7-DE7A-4929-8D67-E72C80773BAD
# 3   4        AZ  D90F1BC7-CD04-409A-9AF7-D4DAB649425A
# 4   5        CA  FD678F86-62B1-4EC4-A628-98AEE7BC74D5
#
#                        Category
# 0  Consumer Financial Questions
# 1  Consumer Financial Questions
# 2  Consumer Financial Questions
# 3  Consumer Financial Questions
# 4  Consumer Financial Questions

# %%
qposts['QuestionUno'].value_counts()
# Out:
# 6BA6DBC2-A629-49AA-B2A1-8A1C90202639    752
# 7DC5D01C-8997-4B9B-9E13-8DF46C4F5549    273
# 1A8A1A18-87BB-4EE8-88DB-5287EDB2FCC5    175
# 75441487-ED6A-45DC-97F4-A4CD0621F104    171
# FA4E98D6-09C0-4ED0-96FB-406B53E1B222    159
#                                        ...
# 20649EEC-B89C-4810-8C81-A2236BDA5103      1
# 60953FD1-9957-47F8-A2FD-6013143CA45E      1
# D5C9CD4D-F81A-4417-AABA-EA38D2CFF050      1
# 4E96632A-98A5-46C8-8C60-0F82B15FF108      1
# B7C95D50-6C81-4E61-BC16-81077B7D3F7E      1
# Name: QuestionUno, Length: 160426, dtype: int64

# %%
qposts[qposts['QuestionUno']=='6BA6DBC2-A629-49AA-B2A1-8A1C90202639']
# Out:
#             Id StateAbbr                           QuestionUno  \
# 218753  243032        NM  6BA6DBC2-A629-49AA-B2A1-8A1C90202639
# 218754  243033        NM  6BA6DBC2-A629-49AA-B2A1-8A1C90202639
# 218755  243034        NM  6BA6DBC2-A629-49AA-B2A1-8A1C90202639
# 218756  243035        NM  6BA6DBC2-A629-49AA-B2A1-8A1C90202639
# 218757  243036        NM  6BA6DBC2-A629-49AA-B2A1-8A1C90202639
# ...        ...       ...                                   ...
# 219500  243799        NM  6BA6DBC2-A629-49AA-B2A1-8A1C90202639
# 219501  243800        NM  6BA6DBC2-A629-49AA-B2A1-8A1C90202639
# 219502  243801        NM  6BA6DBC2-A629-49AA-B2A1-8A1C90202639
# 219503  243802        NM  6BA6DBC2-A629-49AA-B2A1-8A1C90202639
# 219504  243803        NM  6BA6DBC2-A629-49AA-B2A1-8A1C90202639
#
#                                                  PostText           CreatedUtc
# 218753  I am My ex-###yfriend is convinced I have a ba...  2020-07-20 17:13:19
# ...
