# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
attorneys = pd.read_csv("/Users/jessie/Desktop/UCSB/datafest_data/data/attorneys.csv")
attorney_time_entries = pd.read_csv("/Users/jessie/Desktop/UCSB/datafest_data/data/attorneytimeentries.csv")
categories = pd.read_csv("/Users/jessie/Desktop/UCSB/datafest_data/data/categories.csv")
clients = pd.read_csv("/Users/jessie/Desktop/UCSB/datafest_data/data/clients.csv")
question_posts = pd.read_csv("/Users/jessie/Desktop/UCSB/datafest_data/data/questionposts.csv", on_bad_lines = "skip")
questions = pd.read_csv("/Users/jessie/Desktop/UCSB/datafest_data/data/questions.csv")
state_sites = pd.read_csv("/Users/jessie/Desktop/UCSB/datafest_data/data/statesites.csv")
subcategories = pd.read_csv("/Users/jessie/Desktop/UCSB/datafest_data/data/subcategories.csv")
# Out:
# /var/folders/v7/ql1hlrjn2556687_hypw44180000gn/T/ipykernel_9614/2298203592.py:5: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   question_posts = pd.read_csv("/Users/jessie/Desktop/UCSB/datafest_data/data/questionposts.csv", on_bad_lines = "skip")

# %%
client_question = pd.merge(clients, questions, left_on='ClientUno', right_on='AskedByClientUno')

# %%
client_question = client_question.drop(columns=['AskedByClientUno'])

# %%
client_question.head()
# Out:
#    Id_x StateAbbr_x                             ClientUno     County  \
# 0     3          GA  DD5F1EFC-8298-457F-BC09-CABBEB57A697     Barrow
# 1     5          ID  3782D4F9-9B16-4BC8-ADA3-F85CEE200630      Boise
# 2     6          CT  F8C0C4C9-0555-4BAF-9324-B2A8DF4E7DF6  New Haven
# 3    17          MS  E7952D74-AA6D-4B20-BED0-60B8F973EA30  Yalobusha
# 4    19          WY  30B143DC-CA59-4298-B4F5-06ADBE1B00B7    Laramie
#
#      StateName  PostalCode      EthnicIdentity   Age  Gender  \
# 0      Georgia     30157.0  Latino or Hispanic  55.0    Male
# 1        Idaho     83705.0           Caucasian  65.0    Male
# 2  Connecticut      6511.0    African American   NaN  Female
# 3  Mississippi     38965.0           Caucasian   NaN  Female
# 4      Wyoming     82053.0           Caucasian   NaN  Female
#
#          MaritalStatus  ...                           CategoryUno  \
# 0               Single  ...  D15ACC4B-910D-4B26-BA2D-40880D42BD0D
# 1               Single  ...  A1FB3C8A-2622-43BC-8A23-25FFA06B0E60
# 2               Single  ...  EE081096-2C46-4EA3-B7B1-7388963334E4
# 3  Married / remarried  ...  772EC297-5D6F-469A-9F0E-4850311E14DA
# 4  Divorced or Widowed  ...  B493CC26-B797-4A33-BEED-7C7146A3300A
#
#               Category                        SubcategoryUno  \
# 0                Other  E966BD76-8DC1-4292-83EA-BA28BF010927
# 1                Other  D72E18A3-2240-4D8A-AD5F-0B4141731FAA
# 2                Other  110B2BC5-5B0B-4EBD-A689-B55DA5A36363
# 3  Family and Children  471122D1-919D-48C2-A020-3F31EEFB1436
# 4  Family and Children  7820FAD7-6BDF-47AD-88A2-2DB5C6C6FA70
#
#               Subcategory           AskedOnUtc  \
# 0     Disaster Legal Help  2016-10-12 14:43:26
# 1                   Other  2017-02-23 00:17:06
# 2                Criminal  2016-08-29 20:35:03
# 3  Family/Divorce/Custody  2016-09-01 15:59:27
# 4  Family/Divorce/Custody  2016-08-25 21:07:39
#
#                      TakenByAttorneyUno           TakenOnUtc  \
# 0                                   NaN                  NaN
# 1                                   NaN                  NaN
# 2                                   NaN                  NaN
# 3  4AC3D426-AD99-4623-BF48-D0A921A9EB03  2016-09-28 20:08:24
# 4  D292D199-16CE-4019-AAB5-3410C2DFEF92  2016-08-26 17:29:16
#
#    ClosedByAttorneyUno          ClosedOnUtc  LegalDeadline
# 0                  NaN  2017-01-03 20:33:29            NaN
# 1                  NaN                  NaN            NaN
# 2                  NaN  2016-08-31 13:39:41            NaN
# 3                  NaN  2016-10-08 21:25:20            NaN
# 4                  NaN  2016-09-05 17:42:10            NaN
#
# [5 rows x 32 columns]

# %%
zip_map = gpd.read_file("/Users/jessie/Desktop/UCSB/datafest_data/zcta.zip")

# %%
client_question = client_question.dropna()

# %%
zip_map['ZCTA5CE10'] = zip_map['ZCTA5CE10'].astype(int)
client_question['PostalCode'] = client_question['PostalCode'].astype(int)

# %%
merged_df_zip = zip_map.merge(client_question, left_on='ZCTA5CE10', right_on='PostalCode')
merged_df_zip= merged_df_zip.drop(columns=['PostalCode'])

# %%
fig, ax = plt.subplots(figsize=(12, 8))
merged_df_zip.plot(column='ZCTA5CE10', cmap='Reds', linewidth=0.1, edgecolor='gray', ax=ax, legend=True)
plt.title('Most Frequent Postal Codes in the US')
# Out:
# Text(0.5, 1.0, 'Most Frequent Postal Codes in the US')

# %%
states = gpd.read_file("/Users/jessie/Desktop/UCSB/datafest_data/s_22mr22.zip")

# %%
states.head()
# Out:
#   STATE            NAME FIPS        LON       LAT  \
# 0    AK          Alaska   02 -152.24098  64.24019
# 1    AL         Alabama   01  -86.82676  32.79354
# 2    AR        Arkansas   05  -92.43920  34.89977
# 3    AS  American Samoa   60 -170.37215 -14.26486
# 4    AZ         Arizona   04 -111.66457  34.29323
#
#                                             geometry
# 0  MULTIPOLYGON (((-179.10754 51.30120, -179.1054...
# 1  MULTIPOLYGON (((-88.11011 30.25891, -88.10638 ...
# 2  POLYGON ((-91.62986 36.49921, -91.62849 36.499...
# 3  MULTIPOLYGON (((-170.77310 -14.36245, -170.773...
# 4  POLYGON ((-110.49090 37.00361, -110.48750 37.0...

# %%
merged_states = pd.merge(states, client_question, left_on='STATE', right_on='StateAbbr_x')
merged_states = merged_states.drop(columns=['StateAbbr_x'])

# %%
state_counts = pd.DataFrame(merged_states['STATE'].value_counts()).reset_index()

# %%
state_counts = state_counts.rename(columns={'STATE': 'count'})

# %%
state_counts = state_counts.rename(columns={'index': 'STATE'})

# %%
state_counts
# Out:
#    STATE  count
# 0     FL     68
# 1     TX     37
# 2     IL     32
# 3     NC     31
# 4     WI     28
# 5     TN     26
# 6     IN     26
# 7     MO     25
# 8     NY     22
# 9     SC     20
# 10    ME     16
# 11    VA     16
# 12    MA     12
# 13    NE     11
# 14    LA      8
# 15    NJ      8
# 16    MD      8
# 17    HI      6
# 18    GA      6
# 19    SD      5
# 20    NH      5
# 21    WY      4
# 22    PA      3
# 23    UT      3
# 24    WV      3
# 25    CT      3
# 26    CA      3
# 27    AK      3
# 28    OK      2
# 29    IA      2
# 30    AZ      1
# 31    MS      1
# 32    KS      1
# 33    VT      1

# %%
merged_df = states.merge(state_counts, left_on='STATE', right_on='STATE')

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 8))
merged_df.plot(column='count', cmap='OrRd', linewidth=0.5, ax=ax, edgecolor='0.5', legend=True)
ax.axis('off')
ax.set_xlim([-130, -60])  # adjust x limits
ax.set_ylim([25, 50])  # adjust y limits
plt.show()
