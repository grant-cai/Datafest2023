# %%
import pandas as pd 
import re 
import plotly.express as px

# %%
attorneys = pd.read_csv('henry\\attorneys.csv')
attornytime = pd.read_csv('henry\\attorneytimeentries.csv')
categories = pd.read_csv('henry\\categories.csv')
clients = pd.read_csv('henry\\clients.csv')
qposts = pd.read_csv('henry\\questionposts.csv', on_bad_lines = 'skip')
questions = pd.read_csv('henry\\questions.csv')
statesites = pd.read_csv('henry\\statesites.csv')
subcategories = pd.read_csv('henry\\subcategories.csv')
# Out:
# C:\Users\mhenr\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3553: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
postText = qposts['PostText'].tolist()

# %%
len(postText)
# Out:
# 365195

# %%
count = questions['Category'].value_counts(ascending = True )
print(count)
count.index
# Out:
# Juvenile                               357
# Education                              794
# Income Maintenance                    2688
# Health and Disability                 2707
# Individual Rights                     8312
# Work, Employment and Unemployment    10187
# Consumer Financial Questions         17273
# Housing and Homelessness             34755
# Other                                37053
# Family and Children                  88753
# Name: Category, dtype: int64
# Index(['Juvenile', 'Education', 'Income Maintenance', 'Health and Disability',
#        'Individual Rights', 'Work, Employment and Unemployment',
#        'Consumer Financial Questions', 'Housing and Homelessness', 'Other',
#        'Family and Children'],
#       dtype='object')

# %%
fig = px.bar(count, x=count.index, y= count.values)
fig.show()

# %%
questions['ClosedByAttorneyUno']
# Out:
# 0                                          NaN
# 1                                          NaN
# 2         FA34142B-1575-4720-981C-2D28C3560137
# 3         FA34142B-1575-4720-981C-2D28C3560137
# 4                                          NaN
#                           ...
# 202874    6E43EC98-8700-4439-98A9-52B663CCE348
# 202875    FA34142B-1575-4720-981C-2D28C3560137
# 202876                                     NaN
# 202877    6E43EC98-8700-4439-98A9-52B663CCE348
# 202878                                     NaN
# Name: ClosedByAttorneyUno, Length: 202879, dtype: object

# %%
questions['TakenByAttorneyUno']
questions['TakenByAttorneyUno'][0]
# Out:
# nan

# %%
attornytime.head(114812)
# Out:
#             Id StateAbbr                          TimeEntryUno  \
# 0            1        AK  44954D1D-C354-41F6-8C33-327E866B6BA3
# 1            2        AL  F1D8F733-1BDB-47FD-BC7C-CB512E2C5A3A
# 2            3        AR  81ED2628-2FF4-4B67-86B1-F9DFEC603C15
# 3            4        AZ  14B1BCC4-CEF6-4108-AB54-3CDE482845F0
# 4            5        CA  41275A72-CD69-4A42-85FB-E3E4FEE0C316
# ...        ...       ...                                   ...
# 114608  114609        FL  80806E81-DEBF-4698-A86A-01BD77857D31
# 114609  114610        FL  748FABE7-CBAE-4CA8-B5FE-7CFF06ECBFDB
# 114610  114611        FL  06045016-F6A3-4BBA-AA5C-38D79A806008
# 114611  114612        FL  3C1D297C-EF98-445B-B380-B2355437B4B5
# 114612  114613        FL  16326359-39AF-4FDD-8C05-E14385568D07
#
#                                  AttorneyUno  Hours         EnteredOnUtc
# 0       C126C566-9039-4991-BDD8-0CDD05C27DDF    1.8  2017-01-05 21:25:23
# ...

# %%
questions['TakenByAttorneyUno']
empty = pd.DataFrame({'State': [], 'Response':[]})
for i in range(len(questions['TakenByAttorneyUno'])):
    if questions['TakenByAttorneyUno'][i] == 'nan':
        print('hello')
        temp = pd.DataFrameI({'State': [questions['StateAbbr']], 'Response' : ['Yes']})
        empty.append(temp)

    else:
        print('hello')
        temp = pd.DataFrame({'State': [questions['StateAbbr']], 'Response' : ['no']})
        empty.append(temp)
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
questions
# Out:
#             Id StateAbbr                           QuestionUno  \
# 0            1        NC  BB53B2A4-7C1B-45C3-9693-62047889317D
# 1            2        NC  0C49F841-2782-4313-961E-7882B96D0854
# 2            3        NC  BFC28E08-B6B1-4185-A91A-89DF90816BE4
# 3            4        NC  45B24109-243A-489B-B0D2-2F36C2A369FE
# 4            5        NC  C4707F71-FE4A-4154-8174-AF00BEE2B361
# ...        ...       ...                                   ...
# 202874  202875        NC  376FFF48-9068-4A8F-9316-2EB5A7E38001
# 202875  202876        NC  98AA49B1-D423-4D12-9E70-A5BD6663DFE5
# 202876  202877        NC  B80305AA-7509-436E-AFF8-6B33AC682730
# 202877  202878        NC  DC374484-7C6E-44A3-9DB7-89B8868518F1
# 202878  202879        NC  1F2F2FC1-4661-4A14-A7BE-43E883D1BD44
#
#                                  CategoryUno                      Category  \
# 0       C932D197-7F43-4BCF-BE0B-FE5F5DBCB9EF           Family and Children
# ...

# %%
PA = pd.DataFrame(questions.loc[questions['StateAbbr'] == 'AZ'])

# %%
PA.value_counts('AskedByClientUno')
# Out:
# AskedByClientUno
# AD27ABBF-695F-458C-8A11-E98FF3E7A139    17
# 57651C34-212D-4678-8364-FF0C3DB1918A    13
# F2159AFF-F79A-4B1C-9EAE-C280A5255279    11
# CB9A9041-178B-47A4-A247-471ED85CB70E    10
# 24DEFFA5-25C4-44F0-B5EB-0198F36C3190     9
#                                         ..
# 5A575AED-B1EC-4CA3-9BF9-68D973BBB648     1
# 5A5E04D3-7546-43D5-89BB-73C721E19286     1
# 5A69EF18-DE62-4AE2-B902-D9F2F7DC024C     1
# 5A74854D-2805-4653-B2BF-1BD4C2EE82B4     1
# FFF7D1EE-1B9C-469A-AA85-61F07993005C     1
# Length: 4751, dtype: int64

# %%
PA['AskedByClientUno']
# Out:
# 31336     31B52984-BBDD-49E9-B5E5-D1AFBE8196EA
# 31337     9786A409-D7BB-46DE-8DA2-D9A8E2203696
# 31338     9C120201-C56E-4BA5-ACC5-A206410BDBA6
# 31339     C79759B8-5E4C-45ED-9C59-D834FEE2A5F1
# 31340     A9DA20DA-54F3-4008-BA39-A589A510C956
#                           ...
# 201370    19D6FD3B-419B-4D4A-A187-358950C70D5D
# 201371    9947DB6D-7569-42F5-A517-98E3325E8AE3
# 201372    F900C0D0-F275-4C92-9BB3-AB3D27610C7C
# 201373    8DD7A31D-C7BB-4D24-81D9-C638C0805DE6
# 201374    C28E3164-C0E2-4E17-A82D-FAD112F2C6F3
# Name: AskedByClientUno, Length: 5455, dtype: object

# %%
PA_clients = pd.DataFrame(clients.loc[clients['ClientUno'].isin(PA['AskedByClientUno'])])

# %%
PA_clients.value_counts('County')
# Out:
# County
# Maricopa      3130
# Pima           516
# Pinal          252
# Mohave         215
# Yavapai        183
# Yuma           103
# Cochise         92
# Coconino        81
# Gila            46
# Navajo          40
# Apache          27
# La Paz          24
# Graham          21
# Santa Cruz      14
# Greenlee         6
# Other            1
# dtype: int64

# %%
 PA_clients.value_counts('County').to_csv('AZ_county_count.csv')

# %%
clients
# Out:
#             Id StateAbbr                             ClientUno  \
# 0            1        MS  B731DA7A-A97A-4A2E-BF11-0A126A05AF70
# 1            2        MS  8101DB7C-0CC8-4DE9-9E87-71137269AAD5
# 2            3        GA  DD5F1EFC-8298-457F-BC09-CABBEB57A697
# 3            4        TX  21DC9E3D-D0AA-4B85-88BB-428F5BCF7F13
# 4            5        ID  3782D4F9-9B16-4BC8-ADA3-F85CEE200630
# ...        ...       ...                                   ...
# 331421  331422        VA  03092D03-1202-4C99-8927-838FCA7F2A39
# 331422  331423        VA  C00B3F98-3714-4599-9B33-3879E58D9F87
# 331423  331424        VA  8145DA8C-9B10-4429-A3D1-BFF24D6FA73F
# 331424  331425        VA  816CA3A7-0ED7-4A51-8DCF-C1A3FB07EC02
# 331425  331426        VA  256345E3-BB8A-47E9-A695-09EEEE4D88D2
#
#                      County    StateName  PostalCode          EthnicIdentity  \
# 0                Washington  Mississippi     73179.0                     NaN
# ...
